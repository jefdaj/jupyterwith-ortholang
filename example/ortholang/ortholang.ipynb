# %%
"hello ortholang!"
# Out:
# "hello ortholang!"

# %%
list1 = range_integers 1 10
list2 = range_integers 6 15

# %%
venndiagram [list1, list2]

# %%
:type
# Out:
# list1.num.list = range_integers 1 10
# list2.num.list = range_integers 6 15
# result.png = venndiagram [list1, list2]
